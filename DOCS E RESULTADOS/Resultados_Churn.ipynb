# %% [markdown]
# ## **Resultados :**

# %% [markdown]
# Observando o dashboard,vemos varios dados interessantes, e incluindo a lista de clientes que o modelo de Machine Learning nos deu. assim tendo uma direção concreta de onde se deve focar.
#
# **Dados observados**:

# %% [markdown]
# **3 dados foram oq mais me chamaram atenção pela sua diferença grande entre o uma variavel das demais conseguindo assim traçar um perfil de churn que conseguimos criar campanhas e outras soluções.**

# %% [markdown]
# 1 **Categoria de motivos que levaram ao cancelamento do contrato.**

# %% [markdown]
# ![newplot.png](data:image/png;base64,...)

# %% [markdown]
# O dado que inicialmente chamou minha atenção foi a análise de churn por categoria. Observando os resultados, fica evidente que o principal motivo que levou os clientes a cancelarem seus serviços foi '**Concorrente**' . Esse fator aparece como o grande responsável pela evasão de clientes, indicando que a concorrência no mercado está desempenhando um papel crucial na decisão dos consumidores.
#
# Essa informação não apenas destaca a relevância da concorrência, mas também sugere que a empresa precisa reavaliar suas estratégias para se manter competitiva. Algumas possíveis razões para essa perda podem **incluir preços mais atrativos oferecidos pelos concorrentes,**

# %% [markdown]
# **2. Tipo de internet que o cliente estava durante o cancelamento.**

# %% [markdown]
# ![newplot (1).png](data:image/png;base64,...)

# %% [markdown]
# **A fibra óptica** tem o maior número de churns, com 1.136 casos . Isso indica que, embora seja uma tecnologia moderna e desejada pelos clientes, ela também apresenta um alto índice de cancelamentos.
#
# **Analisando os dados,** penso que a concorrencia entra em contato po, os maiores casos de churn são mensais, asism como a fibra optica, seria melhor reavaliar o pacote oferecido pela empresa na distribuição dessa internet.

# %% [markdown]
# **3. Tipo de contrato onde o churn estava durante o cancelamento.**

# %% [markdown]
# ![newplot (2).png](data:image/png;base64,...)

# %% [markdown]
# O contrato mensal tem a maior taxa de churn, representando **77.2% do total**. Isso indica que clientes com contratos mensais são muito mais propensos a cancelar seus serviços em comparação com outros tipos de contratos.
#
# Essa alta taxa pode ser explicada pelo fato de que contratos mensais** oferecem flexibilidade aos clientes, permitindo cancelamentos frequentes sem grandes penalidades ou compromissos prolongados.**
#
# E também vimos que uma boa parte dos casos de churn são Feminino.

# %% [markdown]
# ![newplot (3).png](data:image/png;base64,...)

# %% [markdown]
# Ent temos um publico claro : Clientes cujo contratam o pacote de **Fibra Óptica**, que escolhem o contrato **Mensal** e que majoriatariamente são do público **feminino**.
#
# Possivel solução : **Focar no pacote de curta duração de fibra optica da empresa, além de manter um serviço mais competitivo e no preço ideal para não perder para concorrencia**

# %% [markdown]
# ## **Lista de clientes possiveis a cancelarem o contrato.**
#
# Feito utilizando o modelo **Random Forest.**

# %%
clientespred
# Out:
#     Customer_ID  Churn_Predict  Probabilidade     Gênero  Idade Casado  \
# 0     13717-UTT              1       0.944016  Masculino     56    Sim
# 1     86818-MAH              1       0.841330   Feminino     29    Sim
# 2     76566-UTT              1       0.902227  Masculino     61    Não
# 3     28648-DEL              1       0.740841  Masculino     54    Sim
# 4     33514-UTT              1       0.672581   Feminino     28    Sim
# ..          ...            ...            ...        ...    ...    ...
# 572   32117-TAM              1       0.906128   Feminino     25    Sim
# 573   46848-WES              1       0.656386   Feminino     22    Sim
# 574   81946-TAM              1       0.941953   Feminino     55    Sim
# 575   56232-UTT              1       0.938153   Feminino     79    Sim
# 576   34897-RAJ              1       0.676554   Feminino     45    Sim
#
#             Estado  Número_de_Indicações  Tempo_de_Contrato_Meses    Promoção  \
# ...
